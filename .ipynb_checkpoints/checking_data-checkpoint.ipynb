# %%
import numpy as np
import tensorflow as tf
import pandas as pd

# %%
data = np.load("train.npy")

# %%
print(data)
# Out:
# [['00-0027854' 'Sam Bradford' '22.8141552511' ..., '139.9' '1.7' '8.12']
#  ['00-0022942' 'Philip Rivers' '28.7308219178' ..., '172.2' '2.0' '16.42']
#  ['00-0020531' 'Drew Brees' '31.6283105023' ..., '83.2' '1.2' '10.88']
#  ...,
#  ['00-0029263' 'Russell Wilson' '25.0586757991' ..., '90.5' '2.1' '10.78']
#  ['00-0019596' 'Tom Brady' '36.3799086758' ..., '121.6' '1.8' '6.58']
#  ['00-0024226' 'Jay Cutler' '30.6420091324' ..., '148.8' '1.4' '15.04']]

# %%
df = pd.DataFrame(data=data)

# %%
print(df)
# Out:
#               0                   1              2   3              4   \
# 0     00-0027854        Sam Bradford  22.8141552511   4  26.4907407407
# 1     00-0022942       Philip Rivers  28.7308219178  10           15.0
# 2     00-0020531          Drew Brees  31.6283105023  13           37.0
# 3     00-0022787         Matt Schaub  29.1842465753  10           39.0
# 4     00-0005106         Brett Favre  40.8920091324  15           31.0
# 5     00-0007091     Matt Hasselbeck  34.9342465753  12           30.0
# 6     00-0023541          Kyle Orton   27.797716895   6           56.0
# 7     00-0026993        Josh Freeman  22.6337899543   1           32.0
# 8     00-0021231       David Garrard   32.547716895   5           39.0
# 9     00-0004161       Jake Delhomme  35.6420091324   9           34.0
# 10    00-0026898        Mark Sanchez  23.8059360731   5           16.0
# 11    00-0023436          Alex Smith  26.3168949772   9           28.0
# ...
